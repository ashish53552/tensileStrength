# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

y_test=np.array([[282.],
       [700.],
       [215.],
       [620.],
       [221.],
       [170.],
       [274.],
       [750.],
       [300.],
       [148.],
       [421.],
       [196.],
       [150.],
       [244.],
       [211.],
       [230.]])
X_test=np.array([[ 231.0519  ],
       [ 341.45462 ],
       [ 101.07178 ],
       [ 109.551506],
       [ 177.2433  ],
       [ 121.00362 ],
       [ 267.83398 ],
       [1227.3506  ],
       [ 603.59753 ],
       [ 267.83398 ],
       [ 319.55435 ],
       [ 257.3182  ],
       [ 319.55435 ],
       [ 601.1824  ],
       [ 206.11649 ],
       [ 232.44685 ]])
# Out:
# /home/ashish/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/ashish/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/ashish/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/ashish/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
y_test=pd.DataFrame(data=y_test,columns=['True_Value'],index=range(0,16,1))

# %%
X_test=pd.DataFrame(data=X_test,columns=['Predicted_Value'],index=range(0,16,1))

# %%
true_vs_pred=pd.concat(objs=[y_test,X_test],axis=1)

# %%
index_arr=np.array(range(0,16,1))
true_vs_pred.set_index(index_arr)
true_vs_pred.index
# Out:
# RangeIndex(start=0, stop=16, step=1)

# %%
fig=plt.figure(figsize=(12,8))
ax=fig.add_axes([0.1,0.1,.75,.75])
ax.set_xlabel('index')
ax.set_ylabel('YS_MPA')
ax.set_title('Prediction')
ax.plot(true_vs_pred.index,true_vs_pred['True_Value'],marker="o",label="True_Value",linewidth=2,markersize=12)
ax.plot(true_vs_pred.index,true_vs_pred['Predicted_Value'],marker="v",label="Predicted_Value",linewidth=2,markersize=12)
ax.legend(loc=0)
fig.savefig('softplus.png')
